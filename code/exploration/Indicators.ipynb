# %%
import sys
sys.path.append('../')
from plotting import CandlePlot
import pandas as pd

# %%
from technicals.indicators import BollingerBands, ATR, KeltnerChannels, RSI, MACD

# %%
df = pd.read_pickle("../data/AUD_CAD_H1.pkl")

# %%
df_an = df.copy()

# %%
df_an = MACD(df)

# %%
df_an.tail()
# Out:
#                            time  volume    mid_o    mid_h    mid_l    mid_c  \
# 54512 2024-10-09 19:00:00+00:00    2620  0.92025  0.92087  0.92012  0.92060
# 54513 2024-10-09 20:00:00+00:00    1763  0.92056  0.92142  0.92036  0.92126
# 54514 2024-10-09 21:00:00+00:00     395  0.92111  0.92162  0.91963  0.92054
# 54515 2024-10-09 22:00:00+00:00     772  0.92054  0.92092  0.92037  0.92048
# 54516 2024-10-09 23:00:00+00:00    1011  0.92049  0.92122  0.92046  0.92070
#
#          bid_o    bid_h    bid_l    bid_c    ask_o    ask_h    ask_l    ask_c  \
# 54512  0.92015  0.92078  0.92002  0.92049  0.92035  0.92097  0.92021  0.92072
# 54513  0.92045  0.92133  0.92026  0.92104  0.92068  0.92166  0.92046  0.92147
# 54514  0.92076  0.92076  0.91838  0.92033  0.92146  0.92275  0.92074  0.92074
# 54515  0.92034  0.92071  0.92019  0.92038  0.92074  0.92120  0.92050  0.92058
# 54516  0.92038  0.92112  0.92034  0.92059  0.92060  0.92131  0.92057  0.92081
#
#            MACD    SIGNAL      HIST
# 54512 -0.000004 -0.000042  0.000038
# 54513  0.000096 -0.000014  0.000110
# 54514  0.000116  0.000012  0.000104
# 54515  0.000125  0.000034  0.000091
# 54516  0.000148  0.000057  0.000091

# %%
dfp = df_an.iloc[-600:]
cp = CandlePlot(dfp, candles=True)
cp.show_plot(line_traces=[], sec_traces=[])

# %%
import plotly.graph_objects as go

# %%
cp = CandlePlot(dfp, candles=False)
cp.fig.add_trace(go.Bar(
    x=cp.df_plot.sTime,
    y=cp.df_plot.HIST,
    name="HIST"
))
cp.show_plot(line_traces=['SIGNAL', 'MACD'], sec_traces=[])
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
