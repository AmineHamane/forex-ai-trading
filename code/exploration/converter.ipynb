# %%
import pandas as pd
import pickle

PKL = r"C:\Users\admin\Desktop\Forex_algo\code\data\EUR_USD_M5.pkl"
PAR = r"C:\Users\admin\Desktop\Forex_algo\code\data\EUR_USD_M5.parquet"

# Try safe load
with open(PKL, "rb") as f:
    df = pickle.load(f, encoding="latin1")

# Save as Parquet
df.to_parquet(PAR, index=False)

print("Converted to Parquet:", PAR)
# Out:
# Converted to Parquet: C:\Users\admin\Desktop\Forex_algo\code\data\EUR_USD_M5.parquet
