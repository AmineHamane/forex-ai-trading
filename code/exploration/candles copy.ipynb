# %%
import sys
import os
sys.path.append(os.path.abspath("../"))
import pandas as pd
import plotly.graph_objects as go
import datetime as dt 
from plotting import Candleplot

# %%
from infrastructure.instrument_collection import instrumentCollection as ic

# %%
pair = "GBP_JPY"
granularity = "H4"
df = pd.read_pickle(f"../data/{pair}_{granularity}.pkl")
MA_list = [10 ,20 ,50 ,100 ,200]

# %%
df.columns
# Out:
# Index(['time', 'volume', 'mid_o', 'mid_h', 'mid_l', 'mid_c', 'bid_o', 'bid_h',
#        'bid_l', 'bid_c', 'ask_o', 'ask_h', 'ask_l', 'ask_c'],
#       dtype='object')

# %%
df_ma = df[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c']]

# %%
df_ma.head(10)
# Out:
#                        time    mid_o    mid_h    mid_l    mid_c
# 0 2022-04-14 01:00:00+00:00  164.616  164.686  164.370  164.586
# 1 2022-04-14 05:00:00+00:00  164.584  164.798  164.276  164.698
# 2 2022-04-14 09:00:00+00:00  164.698  164.777  164.358  164.400
# 3 2022-04-14 13:00:00+00:00  164.404  164.525  164.034  164.428
# 4 2022-04-14 17:00:00+00:00  164.430  164.779  164.392  164.655
# 5 2022-04-14 21:00:00+00:00  164.616  165.056  164.408  164.926
# 6 2022-04-15 01:00:00+00:00  164.924  165.282  164.770  165.184
# 7 2022-04-15 05:00:00+00:00  165.184  165.456  165.007  165.284
# 8 2022-04-15 09:00:00+00:00  165.284  165.363  165.102  165.260
# 9 2022-04-15 13:00:00+00:00  165.260  165.323  164.988  165.130

# %%
for ma in MA_list:
    df_ma[f'MA_{ma}'] = df_ma.mid_c.rolling(window=ma).mean()
df_ma.dropna(inplace=True)
df_ma.reset_index(inplace=True, drop=True)
# Out:
# C:\Users\amino\AppData\Local\Temp\ipykernel_27352\1967031491.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\amino\AppData\Local\Temp\ipykernel_27352\1967031491.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\amino\AppData\Local\Temp\ipykernel_27352\1967031491.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\amino\AppData\Local\Temp\ipykernel_27352\1967031491.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\amino\AppData\Local\Temp\ipykernel_27352\1967031491.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\amino\AppData\Local\Temp\ipykernel_27352\1967031491.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_plot = df_ma.iloc[:500]

# %%
df_plot.shape
# Out:
# (500, 10)

# %%
cp = Candleplot(df_plot)
# Out:
# Candlestick figure created.

# %%
traces = [f"MA_{x}" for x in MA_list]

# %%
cp.show_plot(line_traces=traces)

# %%
MA_S = "MA_50"
MA_L = "MA_200"
BUY = 1
SELL = -1
NONE = 0

# %%
df_an = df_ma[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c', MA_S, MA_L]]

# %%
df_an.head(30)
# Out:
#                         time    mid_o    mid_h    mid_l    mid_c      MA_50  \
# 0  2022-05-31 05:00:00+00:00  161.433  161.446  160.945  161.326  160.00048
# 1  2022-05-31 09:00:00+00:00  161.326  161.654  161.053  161.614  160.04116
# 2  2022-05-31 13:00:00+00:00  161.615  162.340  161.596  162.208  160.11652
# 3  2022-05-31 17:00:00+00:00  162.208  162.362  162.010  162.180  160.19844
# 4  2022-05-31 21:00:00+00:00  162.134  162.623  162.102  162.544  160.25960
# 5  2022-06-01 01:00:00+00:00  162.545  162.766  162.389  162.586  160.32280
# 6  2022-06-01 05:00:00+00:00  162.586  163.327  162.454  162.852  160.39480
# 7  2022-06-01 09:00:00+00:00  162.850  163.092  162.686  162.776  160.46768
py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def is_trade(row):
    if row.DELTA >= 0 and row.DELTA_PREV < 0:
        return BUY
    elif row.DELTA < 0 and row.DELTA_PREV >= 0:
        return SELL
    return NONE

# %%
df_an['TRADE'] = df_an.apply(is_trade, axis=1)

# %%
df_trades = df_an[df_an.TRADE != NONE].copy()

# %%
df_trades.head()
# Out:
#                          time    mid_o    mid_h    mid_l    mid_c      MA_50  \
# 24  2022-06-06 05:00:00+00:00  163.326  164.459  163.120  164.392  161.60064
# 169 2022-07-08 09:00:00+00:00  161.999  163.584  161.901  163.529  163.93832
# 236 2022-07-25 13:00:00+00:00  164.820  165.093  164.292  164.740  164.69278
# 263 2022-08-01 01:00:00+00:00  161.767  161.832  161.046  161.542  164.36944
# 430 2022-09-07 21:00:00+00:00  165.785  166.325  165.761  166.083  162.52420
#
#          MA_200     DELTA  DELTA_PREV  TRADE
# 24   161.523375  0.077265   -0.050600      1
# 169  163.947075 -0.008755    0.057265     -1
# 236  164.651470  0.041310   -0.005960      1
# 263  164.414380 -0.044940    0.035605     -1
# 430  162.482745  0.041455   -0.039300      1

# %%
cp = Candleplot(df_an.iloc[200:280])
cp.show_plot(line_traces=[MA_S, MA_L])
# Out:
# Candlestick figure created.

# %%
ic.LoadInstruments("../data")

# %%
ic.instruments_dict[pair]
# Out:
# {'name': 'GBP_JPY', 'ins_type': 'CURRENCY', 'displayName': 'GBP/JPY', 'pipLocation': 0.01, 'tradeUnitsPrecision': 0, 'marginRate': 0.069}

# %%
ins_data = ic.instruments_dict[pair]

# %%
df_trades.head()
# Out:
#                          time    mid_o    mid_h    mid_l    mid_c      MA_50  \
# 24  2022-06-06 05:00:00+00:00  163.326  164.459  163.120  164.392  161.60064
# 169 2022-07-08 09:00:00+00:00  161.999  163.584  161.901  163.529  163.93832
# 236 2022-07-25 13:00:00+00:00  164.820  165.093  164.292  164.740  164.69278
# 263 2022-08-01 01:00:00+00:00  161.767  161.832  161.046  161.542  164.36944
# 430 2022-09-07 21:00:00+00:00  165.785  166.325  165.761  166.083  162.52420
#
#          MA_200     DELTA  DELTA_PREV  TRADE
# 24   161.523375  0.077265   -0.050600      1
# 169  163.947075 -0.008755    0.057265     -1
# 236  164.651470  0.041310   -0.005960      1
# 263  164.414380 -0.044940    0.035605     -1
# 430  162.482745  0.041455   -0.039300      1

# %%
df_trades['DIFF'] = df_trades.mid_c.diff().shift(-1)
df_trades.fillna(0, inplace=True)

# %%
df_trades['GAIN'] = df_trades['DIFF'] / ins_data.pipLocation
df_trades['GAIN'] = df_trades['GAIN'] * df_trades['TRADE']

# %%
df_trades.GAIN.sum()
# Out:
# np.float64(-2719.899999999995)

# %%
df_trades['GAIN_C'] = df_trades['GAIN'].cumsum()

# %%
cp = Candleplot(df_trades, candles=False)
cp.show_plot(line_traces=['GAIN_C'])
# Out:
# Candlestick figure created.
